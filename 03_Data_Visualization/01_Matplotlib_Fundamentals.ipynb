# %% [markdown]
# # Matplotlib Fundamentals
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. This notebook covers the core plotting functions in Matplotlib including:
# *   Line Plots (2D visualizations)
# *   Bar Charts
# *   Pie Charts
# *   Basic Formatting & Syntax Rules

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
super=pd.read_csv("Superstore.csv")

# %%
super.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
categeory=super['Category']
super['']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Aditya Sarapure\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 categeory=super['Category']
# ...

# %%
for col in ['Order Date','Ship Date']:
    super[col]=pd.to_datetime(super[col],format='mixed')#

# %%
super['year']=super['Order Date'].dt.year

# %% [markdown]
# ## 1 Line Plot ( 2D visual)

# %% [markdown]
# ### syntax :
#      plt.plot(x,y)
# ### ex:
#      plt.plot(df['year'],df['Sales'])
#
#
#      sort the x values first then plot the graph

# %%
super['year']
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: year, Length: 9994, dtype: int32

# %%
plt.plot(super['year'],super['Profit'],color='red')

# %%
df = pd.DataFrame({'year':[2013,2011,2011,2013,2015],
                   'sales':[1000,2000,3000,2000,3000]})

# %%
df=df.sort_values('year')

# %%
plt.plot(df['year'],df['sales'],color='red',marker='*',label= 'Year vs Sales')
plt.xlabel('Year')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# Line plot
#
#  What not to do ?
#
# df.plot(df['year'],df['Ratings']) We should do like this we will not get the line plot neatly
#
# Apply GROUP by on "X" then do it

# %%
group=df.groupby('year')

# %%
group.head()
# Out:
#    year  sales
# 1  2011   2000
# 2  2011   3000
# 0  2013   1000
# 3  2013   2000
# 4  2015   3000

# %%
plt.plot(group['year'],group['sales'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plt.plot(group['year'],group['sales'])
#
# File c:\Users\Aditya Sarapure\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# File c:\Users\Aditya Sarapure\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:1779, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %% [markdown]
# ---
# ## 📊 Bar Charts & Pie Charts
#
# *(This section is consolidated from `barplot.ipynb`)*
#
# Exploring categorical data distributions using bar plots and pie charts.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
student=pd.DataFrame({
    'no':[5,10,7],
    'sub':['sci','math','eng']
})

# %%
df=pd.read_csv("googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
cat_rating=df.groupby('Category')['Rating'].mean()

# %%
df['Last Updated']=df['Last Updated'].replace({"1.0.19":"January 1,2018"})
df['Last Updated']=pd.to_datetime(df['Last Updated'],format='mixed')
df['year']=df['Last Updated'].dt.year

# %%
df['Last Updated']
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10836   2017-07-25
# 10837   2018-07-06
# 10838   2017-01-20
# 10839   2015-01-19
# 10840   2018-07-25
# Name: Last Updated, Length: 10841, dtype: datetime64[ns]

# %%
plt.bar(cat_rating.index,cat_rating.values)
plt.grid()
plt.xticks(rotation=90)
plt.show()

# %%
df['Installs']
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10836         5,000+
# 10837           100+
# 10838         1,000+
# 10839         1,000+
# 10840    10,000,000+
# Name: Installs, Length: 10841, dtype: object

# %%
cat_sum=df.groupby('Category')['Installs'].sum()

# %%
df['Installs'].dtype
# Out:
# dtype('O')

# %%
df['Installs']=df['Installs'].str.replace('+','')
df['Installs']=df['Installs'].str.replace(',','')
df = df[df['Installs'] != 'Free']
df['Installs']=df['Installs'].astype(int)

# %%
cat_sum=df.groupby('Category')['Installs'].sum()

# %%
plt.bar(cat_sum.index,cat_sum.values)
plt.title('Category Vs Category Values Sum')
plt.xticks(rotation=90)
plt.show()

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'year'],
#       dtype='object')

# %%
Category_vc=df['Category'].value_counts()

# %%
Category_vc.head(10)
# Out:
# Category
# FAMILY             1972
# GAME               1144
# TOOLS               843
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     392
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: count, dtype: int64

# %%
plt.figure(figsize=(15,10))
plt.bar(Category_vc.index,Category_vc.values,width=0.7)
plt.xlabel('Category')
plt.ylabel('Total')
plt.xticks(rotation=100)
plt.show()

# %%
Category_vc.plot(kind='bar')
# Out:
# <Axes: xlabel='Category'>

# %%
app_vc=df['App'].value_counts()

# %%
app_vc
# Out:
# App
# ROBLOX                                                9
# CBS Sports App - Scores, News, Stats & Watch Live     8
# ESPN                                                  7
# Duolingo: Learn Languages Free                        7
# Candy Crush Saga                                      7
#                                                      ..
# Meet U - Get Friends for Snapchat, Kik & Instagram    1
# U-Report                                              1
# U of I Community Credit Union                         1
# Waiting For U Launcher Theme                          1
# iHoroscope - 2018 Daily Horoscope & Astrology         1
# Name: count, Length: 9659, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size  Installs  Type Price Content Rating  \
# 0     159   19M     10000  Free     0       Everyone
# 1     967   14M    500000  Free     0       Everyone
# 2   87510  8.7M   5000000  Free     0       Everyone
# 3  215644   25M  50000000  Free     0           Teen
# 4     967  2.8M    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df['Reviews']=df['Reviews'].astype(int)

# %%
df['Reviews'].dtype
# Out:
# dtype('int32')

# %%
Category=df.groupby('Category')['Reviews'].sum()

# %%
Category
# Out:
# Category
# ART_AND_DESIGN            1714440
# AUTO_AND_VEHICLES         1163666
# BEAUTY                     396240
# BOOKS_AND_REFERENCE      21959069
# BUSINESS                 13954552
# COMICS                    3383276
# COMMUNICATION           815462260
# DATING                    7291278
# EDUCATION                39595786
# ENTERTAINMENT            59178154
# EVENTS                     161018
# FAMILY                  410226330
# FINANCE                  17550728
# FOOD_AND_DRINK            8883330
# GAME                   1585422349
# HEALTH_AND_FITNESS       37893743
# HOUSE_AND_HOME            3976385
# LIBRARIES_AND_DEMO        1037118
# LIFESTYLE                12882784
# MAPS_AND_NAVIGATION      30659254
# MEDICAL                   1585975
# NEWS_AND_MAGAZINES       54400863
# PARENTING                  958331
# PERSONALIZATION          89346140
# PHOTOGRAPHY             213516650
# PRODUCTIVITY            114116975
# SHOPPING                115041222
# ...

# %%
Category.values
# Out:
# array([   1714440,    1163666,     396240,   21959069,   13954552,
#           3383276,  815462260,    7291278,   39595786,   59178154,
#            161018,  410226330,   17550728,    8883330, 1585422349,
#          37893743,    3976385,    1037118,   12882784,   30659254,
#           1585975,   54400863,     958331,   89346140,  213516650,
#         114116975,  115041222,  621241422,   70830169,  273185044,
#          62617919,  110380188,   14604735])

# %%
plt.figure(figsize=(20,20))
plt.bar(Category.index,Category.values)
plt.xticks(rotation=90)
plt.show()

# %%
Category_installs=df.groupby('Category')['Installs'].sum()

# %%
Category_installs
# Out:
# Category
# ART_AND_DESIGN           124338100
# AUTO_AND_VEHICLES         53130211
# BEAUTY                    27197050
# BOOKS_AND_REFERENCE     1921469576
# BUSINESS                1001914865
# COMICS                    56086150
# COMMUNICATION          32647276251
# DATING                   264310807
# EDUCATION                871452000
# ENTERTAINMENT           2869160000
# EVENTS                    15973161
# FAMILY                 10258263505
# FINANCE                  876648734
# FOOD_AND_DRINK           273898751
# GAME                   35086024415
# HEALTH_AND_FITNESS      1583072512
# HOUSE_AND_HOME           168712461
# LIBRARIES_AND_DEMO        62995910
# LIFESTYLE                537643539
# MAPS_AND_NAVIGATION      724281890
# MEDICAL                   53257437
# NEWS_AND_MAGAZINES      7496317760
# PARENTING                 31521110
# PERSONALIZATION         2325494782
# PHOTOGRAPHY            10088247655
# PRODUCTIVITY           14176091369
# ...

# %%
plt.bar(Category_installs.index,Category_installs.values)
plt.xticks(rotation=90)
plt.show()

# %%
category_rat=df.groupby('Category')['Rating'].mean()

# %%
category_rat
# Out:
# Category
# ART_AND_DESIGN         4.358065
# AUTO_AND_VEHICLES      4.190411
# BEAUTY                 4.278571
# BOOKS_AND_REFERENCE    4.346067
# BUSINESS               4.121452
# COMICS                 4.155172
# COMMUNICATION          4.158537
# DATING                 3.970769
# EDUCATION              4.389032
# ENTERTAINMENT          4.126174
# EVENTS                 4.435556
# FAMILY                 4.192272
# FINANCE                4.131889
# FOOD_AND_DRINK         4.166972
# GAME                   4.286326
# HEALTH_AND_FITNESS     4.277104
# HOUSE_AND_HOME         4.197368
# LIBRARIES_AND_DEMO     4.178462
# LIFESTYLE              4.094904
# MAPS_AND_NAVIGATION    4.051613
# MEDICAL                4.189143
# NEWS_AND_MAGAZINES     4.132189
# PARENTING              4.300000
# PERSONALIZATION        4.335987
# PHOTOGRAPHY            4.192114
# PRODUCTIVITY           4.211396
# SHOPPING               4.259664
# SOCIAL                 4.255598
# SPORTS                 4.223511
# ...

# %%
plt.figure(figsize=(9,8))
plt.bar(category_rat.index,category_rat.values)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Pie Chart
# o.To show the percentage
# o.
# syntax:
#    plt.pie(values,labels,autopct="%1.1f")

# %%
Category_vc.values
# Out:
# array([1972, 1144,  843,  463,  460,  424,  392,  387,  384,  382,  366,
#         341,  335,  295,  283,  260,  258,  234,  231,  175,  156,  149,
#         137,  127,   88,   85,   85,   82,   65,   64,   60,   60,   53],
#       dtype=int64)

# %%
plt.pie(Category_vc.values,labels=Category_vc.index,autopct="%1.1f%%")
plt.show()

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'year'],
#       dtype='object')

# %%
# to know category columns in the data set 
df.select_dtypes(include='object').columns # returns categorycal columns
# Out:
# Index(['App', 'Category', 'Size', 'Type', 'Price', 'Content Rating', 'Genres',
#        'Current Ver', 'Android Ver'],
#       dtype='object')

# %%
df.select_dtypes(exclude='object').columns # Returns non categorycal columns
# Out:
# Index(['Rating', 'Reviews', 'Installs', 'Last Updated', 'year'], dtype='object')

# %%
df.select_dtypes(include='number').columns # returns all numeric columns float and int
# Out:
# Index(['Rating', 'Reviews', 'Installs', 'year'], dtype='object')

# %%
df.select_dtypes(include='object').nunique()
# Out:
# App               9659
# Category            33
# Size               461
# Type                 2
# Price               92
# Content Rating       6
# Genres             119
# Current Ver       2831
# Android Ver         33
# dtype: int64

# %%
df['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10840, dtype: object

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type Price Content Rating  \
# 0      159   19M     10000  Free     0       Everyone
# 1      967   14M    500000  Free     0       Everyone
# 2    87510  8.7M   5000000  Free     0       Everyone
# 3   215644   25M  50000000  Free     0           Teen
# 4      967  2.8M    100000  Free     0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df['Price'] = df['Price'].str.replace('$', '')
df['Price'] = df['Price'].astype(float)

# %%
rating_g=df.groupby('Rating')['Installs'].sum().head(8)

# %%
rating_g
# Out:
# Rating
# 1.0      5170
# 1.2      1000
# 1.4      7000
# 1.5      1105
# 1.6    152000
# 1.7     81700
# 1.8    519500
# 1.9    389000
# Name: Installs, dtype: int64

# %%
plt.figure(figsize=(8,10))
plt.pie(rating_g.values,labels=rating_g.index,autopct='%1.1f%%')
plt.show()

# %%
df['Genres'].dtype
# Out:
# dtype('O')

# %%
df['Genres']=df['Genres'].str.replace('nan','')

# %%
df['Genres']
# Out:
# 0                     Art & Design
# 1        Art & Design;Pretend Play
# 2                     Art & Design
# 3                     Art & Design
# 4          Art & Design;Creativity
#                    ...
# 10836                    Education
# 10837                    Education
# 10838                      Medical
# 10839            Books & Reference
# 10840                    Lifestyle
# Name: Genres, Length: 10840, dtype: object

# %%
geners_g=df.groupby('Genres')['Rating'].mean().head(10)

# %%
geners_g.values
# Out:
# array([4.28547486, 4.31176471, 4.18082192, 4.42307692, 4.6       ,
#        4.1       , 4.30434783, 4.34666667, 4.5       , 4.35892857])

# %%
plt.pie(geners_g.values,labels=geners_g.index,autopct='%1.1f%%')
plt.show()

# %%
# from kaggel take any dataset to cleaning and plot all the graphs which are thougth

# %%
df.corr(numeric_only=True)
# Out:
#             Rating   Reviews  Installs     Price      year
# Rating    1.000000  0.068141  0.051355 -0.021903  0.137714
# Reviews   0.068141  1.000000  0.643122 -0.009667  0.075537
# Installs  0.051355  0.643122  1.000000 -0.011689  0.089368
# Price    -0.021903 -0.009667 -0.011689  1.000000 -0.007897
# year      0.137714  0.075537  0.089368 -0.007897  1.000000

# %% [markdown]
# # SEABORN vs MATPLOTLIB

# %% [markdown]
# import seaborn as sns

# %%
import seaborn as sns

# %%
df.head(1)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
#
#    Reviews Size  Installs  Type  Price Content Rating        Genres  \
# 0      159  19M     10000  Free    0.0       Everyone  Art & Design
#
#   Last Updated Current Ver   Android Ver  year
# 0   2018-01-07       1.0.0  4.0.3 and up  2018

# %%
sns.lineplot(x='Rating',y='Price',data=df,hue='Type')
# shaded part is confidence interval
# Out:
# <Axes: xlabel='Rating', ylabel='Price'>

# %%
sns.lineplot(x='year',y='Price',data=df,hue='Type')
# Out:
# <Axes: xlabel='year', ylabel='Price'>

# %%
sns.scatterplot(x="Rating",y="Price",data=df,hue='Type')
# Out:
# <Axes: xlabel='Rating', ylabel='Price'>

# %%
df['Type']
# Out:
# 0        Free
# 1        Free
# 2        Free
# 3        Free
# 4        Free
#          ...
# 10836    Free
# 10837    Free
# 10838    Free
# 10839    Free
# 10840    Free
# Name: Type, Length: 10840, dtype: object

# %%
data_type=df.groupby('Type')

# %%
df_free=data_type.get_group('Free')
df_paid=data_type.get_group('Paid')

# %%
plt.scatter(df_free['Rating'],df_free['Price'])
plt.scatter(df_paid['Rating'],df_paid['Price'])

# %%
sns.scatterplot()
# Out:
# <Axes: >

# %%
sns.scatterplot(x=df_paid['Rating'],y=df_paid['Price'],hue=df['Type'])
sns.scatterplot(x=df_free['Rating'],y=df_free['Price'],hue=df['Type'])
# Out:
# <Axes: xlabel='Rating', ylabel='Price'>

# %%
df[['Rating','Price']].corr()
# Out:
#           Rating     Price
# Rating  1.000000 -0.021903
# Price  -0.021903  1.000000

# %%
df[['Rating','Installs']].corr()
# Out:
#             Rating  Installs
# Rating    1.000000  0.051355
# Installs  0.051355  1.000000

# %%
df[['Price','Installs']].corr()
# Out:
#              Price  Installs
# Price     1.000000 -0.011689
# Installs -0.011689  1.000000

# %%
df[['Price','Reviews']].corr()
# Out:
#             Price   Reviews
# Price    1.000000 -0.009667
# Reviews -0.009667  1.000000

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews  Size  Installs  Type  Price Content Rating  \
# 0      159   19M     10000  Free    0.0       Everyone
# 1      967   14M    500000  Free    0.0       Everyone
# 2    87510  8.7M   5000000  Free    0.0       Everyone
# 3   215644   25M  50000000  Free    0.0           Teen
# 4      967  2.8M    100000  Free    0.0       Everyone
#
#                       Genres Last Updated         Current Ver   Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0  4.0.3 and up
# ...

# %%
df['Category'].nunique()
# Out:
# 33

# %%
category_group=df.groupby('Category')
category_rating_avg=category_group['Rating'].mean().sort_values(ascending=False).head(10)

# %%
year_group=df.groupby('year')
year_rating_avg=year_group['Rating'].mean()

# %%
category_rating_avg
# Out:
# Category
# EVENTS                 4.435556
# EDUCATION              4.389032
# ART_AND_DESIGN         4.358065
# BOOKS_AND_REFERENCE    4.346067
# PERSONALIZATION        4.335987
# PARENTING              4.300000
# GAME                   4.286326
# BEAUTY                 4.278571
# HEALTH_AND_FITNESS     4.277104
# SHOPPING               4.259664
# Name: Rating, dtype: float64

# %%
plt.figure(figsize=(10,7))
plt.bar(category_rating_avg.index,category_rating_avg.values)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x=df['Category'],y=df['Rating'])
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
sns.barplot(x=df['year'],y=df['Price'],hue=df['Type'])
# Out:
# <Axes: xlabel='year', ylabel='Price'>

# %%
sns.barplot(x=df['year'],y=df['Rating'],hue=df['Type'])
# Out:
# <Axes: xlabel='year', ylabel='Rating'>

# %%
df['year'].nunique()
# Out:
# 9

# %% [markdown]
# ## Heatmap
#   syntax :
#      sns.heatmap(df.corr())

# %%
df['Size']=df['Size'].str.replace('M','')

df['Size']=df['Size'].str.replace('Varies with device',' ')

#df['Size']=df['Size'].astype(float)

# %%
df['Size']=df['Size'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df['Size']=df['Size'].astype(float)
#
# File c:\Users\Aditya Sarapure\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\Aditya Sarapure\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# ### SUBPLOT
#   syntax:
#      fig,ax=plt.subplot((row,col),figsize=(width,height))

# %%
# fig,ax=plt.subplots(nrows=1,ncols=3)
fig,ax=plt.subplots(2,3,figsize=(20,10))
ax[0,0].plot(year_rating_avg,marker='o')
ax[0,1].bar(category_rating_avg.index,category_rating_avg.values)
ax[0,2].pie(geners_g.values,labels=geners_g.index,autopct='%1.1f%%')
ax[1,0].bar(category_rating_avg.index,category_rating_avg.values)
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="coolwarm",ax=ax[1,1])
sns.lineplot(x='Rating',y='Price',data=df,hue='Type',ax=ax[1,2])
fig.savefig('output.png')# .jpg or .jpeg

plt.show()
